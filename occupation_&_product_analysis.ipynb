# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as pl
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cleaned_BlackFriday_sales.csv")
df.drop("Unnamed: 0",inplace=True,axis=1)

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# which occupation spend the most on purchases?

# %%
df.groupby("Occupation").sum()["Purchase"].sort_values().plot(kind="bar",title="Total expenditure")
#sns.countplot(df["Occupation"])
# Out:
# <Axes: title={'center': 'Total expenditure'}, xlabel='Occupation'>

# %% [markdown]
# from the Bar graph we can say that occupation 4 spend the most on purchases this can be attributed to the fact occupation 4 done the most number of purchases followed by 0,7 and so on.

# %% [markdown]
# Which occupation done the most number of purchases?

# %%
df.groupby("Occupation").size().sort_values().plot(kind="bar",title="Total expenditure")
# Out:
# <Axes: title={'center': 'Total expenditure'}, xlabel='Occupation'>

# %% [markdown]
# from the Bar graph we can say that occupation 4 done the most number of purchases followed by 0,7 and so on.

# %% [markdown]
# which of Occupations has the highest mean expenditures on purchases?

# %%
df.groupby("Occupation")["Purchase"].mean().sort_values().plot(kind="bar",title="Total expenditure")
# Out:
# <Axes: title={'center': 'Total expenditure'}, xlabel='Occupation'>

# %% [markdown]
# From the graphs, we can conclude that occupation 17 the highest mean expendituer on purchases, closely followed by occupations 12 and 15. On the other hand, occupation 9 has the lowest mean expenditure.

# %% [markdown]
# Which occupation has the highest participation of married individuals, and which one has the highest participation of unmarried individuals?

# %%
sns.countplot(x="Occupation",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# occupation 4 most population of unmarried individuals this can be attributed to the reason occupation 4 is mostly prefered by males.while occupation 0 has the most number of married individuals.

# %% [markdown]
# which occupation is done by the most number of males and females?

# %%
sns.countplot(x="Occupation",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# Occupation 4 has the highest male participation, followed by occupations 0, 7, 17, and others. In contrast, females predominantly prefer occupation 0 this can be attributed to the reason most of the individuals were married followed by occupations 1, 4, and others.

# %% [markdown]
# Which occupation requires the widest variety of products?

# %%
df.groupby("Occupation")["Product_ID"].nunique().plot(kind="bar",title="Total products")
# Out:
# <Axes: title={'center': 'Total products'}, xlabel='Occupation'>

# %% [markdown]
# The occupation 0 which require the most wide variety of products to work and most of the occupations need more than 1000 products to work.

# %% [markdown]
# which product contribute the most income in the product_category_1?

# %%
df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# 1 in product_category_1 contribute signficantly more  income than any other product approximately 1.75 billions

# %% [markdown]
# which is the costliest sold product in the product_category_1?

# %%
df.groupby("Product_Category_1")["Purchase"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# product 10 is the costliest product in Product_Category_1 followed by 7,6,9 and others

# %% [markdown]
# List the Top 10  products that contributed the most to the income?

# %%
df.groupby("Product_ID").sum()["Purchase"].nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# The product that generated the highest income was P00025442, primarily because it was the most sold item. However, it is important to note that the lists of top-selling products and top income-generating products may not always align. This is due to the fact that a product with the highest sales volume could have a lower price point, which might result in less overall income compared to a higher-priced product with fewer sales

# %% [markdown]
# Top 10 most costliest products?

# %%
df.groupby("Product_ID")["Purchase"].mean().sort_values().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# From the graph we can conclude that P00321442 is the costliest product sold.

# %% [markdown]
# list the top 10 most selling products?

# %%
df.groupby("Product_ID").size().nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# From the above graph we can observe that product P00265242 is the most sold one and product P00059442 is the least sold in the top 10 most sold products
